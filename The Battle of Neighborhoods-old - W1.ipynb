# %% [markdown]
# # Capstone Project - The Battle of Neighborhoods (Week 1)

# %% [markdown]
# Now that you have been equipped with the skills and the tools to use location data to explore a geographical location, over the course of two weeks, you will have the opportunity to be as creative as you want and come up with an idea to leverage the Foursquare location data to explore or compare neighborhoods or cities of your choice or to come up with a problem that you can use the Foursquare location data to solve. If you cannot think of an idea or a problem, here are some ideas to get you started:
#
# 1. In Module 3, we explored New York City and the city of Toronto and segmented and clustered their neighborhoods. Both cities are very diverse and are the financial capitals of their respective countries. One interesting idea would be to compare the neighborhoods of the two cities and determine **how similar or dissimilar they are**. **Is New York City more like Toronto or Paris or some other multicultural city?** I will leave it to you to refine this idea.
# 2. In a city of your choice, if someone is looking to **open a restaurant**, where would you recommend that they open it? Similarly, if **a contractor is trying to start their own business, where would you recommend that they setup their office?**
# These are just a couple of many ideas and problems that can be solved using location data in addition to other datasets. No matter what you decide to do, make sure to provide sufficient justification of **why you think what you want to do or solve is important** and **why would a client or a group of people be interested in your project**.

# %% [markdown]
# These are just a couple of many ideas and problems that can be solved using location data in addition to other datasets. No matter what you decide to do, make sure to provide sufficient justification of why you think what you want to do or solve is important and why would a client or a group of people be interested in your project.

# %% [markdown]
# ## Review criteria

# %% [markdown]
# This capstone project will be graded by your peers. This capstone project is worth 70% of your total grade. The project will be completed over the course of 2 weeks. Week 1 submissions will be worth 30% whereas week 2 submissions will be worth 40% of your total grade.
#
# For this week, you will required to submit the following:
#
# 1. A description of the **problem** and a discussion of the **background**. (15 marks)
#     * Clearly **define a problem or an idea of your choice**, **where you would need to leverage the Foursquare location data to solve or execute**. Remember that data science problems always target an audience and are meant to **help a group of stakeholders solve a problem**, so make sure that you explicitly **describe your audience and why they would care about your problem**.
#     * This submission will eventually become your **Introduction/Business Problem section** in your final report. So I recommend that you push the report (having your Introduction/Business Problem section only for now) to your Github repository and submit a link to it.
# 2. A description of the **data** and how it will be used to solve the problem. (15 marks)
#     * **Describe the data that you will be using to solve the problem or execute your idea**. Remember that you will need to use the **Foursquare location data** to solve the problem or execute your idea. You can absolutely **use other datasets in combination with the Foursquare location data**. So make sure that you provide **adequate explanation and discussion**, **with examples, of the data that you will be using**, even if it is only Foursquare location data.
#     * This submission will eventually become your **Data section** in your final report. So I recommend that you push the report (having your Data section) to your Github repository and submit a link to it.
#
# For the second week, the final deliverables of the project will be:
#
# 1. A link to your Notebook on your Github repository, showing your code. (15 marks)
# 2. A full report consisting of all of the following components (15 marks):
#     * **Introduction** where you discuss the business problem and who would be interested in this project.
#     * **Data** where you describe the data that will be used to solve the problem and the source of the data.
#     * **Methodology** section which represents the main component of the report where you discuss and describe any exploratory data analysis that you did, any inferential statistical testing that you performed, and what machine learnings were used and why.
#     * **Results** section where you discuss the results.
#     * **Discussion** section where you discuss any observations you noted and any recommendations you can make based on the results.
#     * **Conclusion** section where you conclude the report.
# 3. Your choice of a presentation or blogpost. (10 marks)

# %% [markdown]
# # Coursera Capstone Project

# %% [markdown]
# ## The Battle of Neighborhoods (Week 1)

# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ### Coursera Capstone - REPORT CONTENT

# %% [markdown]
# 1. Introduction Section : ⁃ Discussion of the business problem and the interested audience in this project.
# 2. Data Section:
# ⁃ Description of the data that will be used to solve the problem and the sources.
# 3. Methodology section ⁃ Discussion and description of exploratory data analysis carried out, any inferential statistical testing performed, and if any machine learnings were used establishing the strategy and purposes.
# 4. Results section ⁃ Discussion of the results.
# 5. Discussion section ⁃ Elaboration and discussion on any observations noted and any recommendations suggested based on the results.
# 6. Conclusion section ⁃ Report Conclusion.

# %% [markdown]
# # A description of the problem and a discussion of the background. (15 marks)

# %% [markdown]
# ## 1. Introduction Section

# %% [markdown]
# ### Discussion of the business problem and the audience who would be interested in this project.

# %% [markdown]
# ### Business Problem:

# %% [markdown]
# I have been renting an apartment at San Jose area more than ten years. The leasing rate of a two beds room apartment has been raising dramatically since the crashing of economic bubble at 2008. We pay around 5,000 for our small town house now rather than 2,200 per month ten years ago. My family is pushing me lately to search and planning to buy a house by ourselves if the price is within our budget. I am very excited and I want to use this opportunity to practice what I learned of this course in order to answer relevant questions arisen. The key question is : How can I find a convenient and enjoyable place similar to my current resident area? I can use the FourSquare API we've learned at this course and some available real estate API available in the market such as ZillowAPI for example. The idea is to use this chance to practise and apply the knowledge and tools I have learned so far. In order to make a comparison and evaluation of the housing price in Bay Area, here below is my requirements:
#
# - The ammenities in the selected neighborhood shall be similar to my current residence
# - The price is around 1.5M
# - House must be at least 3 bedrooms
# - More than 2 bathrooms
# - 1 car garage
# - House must be more that 1,500 square foot
# - The location is near the supermarket within 1 mile radius
# - The location is near the shopping mall within 5 mile radius
# - The location is close to venues such as restaurants (Asian and Mexicon foods ...etc), parks and coffee shops
#
# Base on the requirements listed above, I finalize the business problem as:
#
# **How to find a suitable house which complies with the requirements on price, features, location and venues?**

# %% [markdown]
# ### The audience who would be interested in this project:
# This case is also applicable for anyone interested in exploring the ways of searching and analysis the location and real estate data for finding a suitable house to buy in Bay Area

# %% [markdown]
# # A description of the data and how it will be used to solve the problem. (15 marks)

# %% [markdown]
# ## 2. Data Section

# %% [markdown]
# ### Description of the data and its sources that will be used to solve the problem

# %% [markdown]
# ### Description of the Data:

# %% [markdown]
# The following data is required to answer the issues of the problem:
# - List of Boroughs and neighborhoods of Manhattan with their geodata (latitud and longitud)
# - List of Subway metro stations in Manhattan with their address location
# - List of apartments for rent in Manhattan area with their addresses and price
# - Preferably, a list of apartment for rent with additional information, such as price, address, area, # of beds, etc
# - Venues for each Manhattan neighborhood ( than can be clustered)
# - Venues for subway metro stations, as needed

# %% [markdown]
# ### How the data will be used to solve the problem

# %% [markdown]
# The data will be used as follows:
# - Use Foursquare and geopy data to map top 10 venues for all Manhattan neighborhoods and clustered in groups ( as per Course LAB)
# - Use foursquare and geopy data to map the location of subway metro stations , separately and on top of the above clustered map in order to be able to identify the venues and ammenities near each metro station, or explore each subway location separately
# - Use Foursquare and geopy data to map the location of rental places, in some form, linked to the subway locations.
# - create a map that depicts, for instance, the average rental price per square ft, around a radious of 1.0 mile (1.6 km) around each subway station - or a similar metrics. I will be able to quickly point to the popups to know the relative price per subway area.
# - Addresses from rental locations will be converted to geodata( lat, long) using Geopy-distance and Nominatim.
# - Data will be searched in open data sources if available, from real estate sites if open to reading, libraries or other government agencies such as Metro New York MTA, etc.
#
# The procesing of these DATA will allow to answer the key questions to make a decision:
#
# - what is the cost of rent (per square ft) around a mile radius from each subway metro station?
# - what is the area of Manhattan with best rental pricing that meets criteria established?
# - What is the distance from work place ( Park Ave and 53 rd St) and the tentative future home?
# - What are the venues of the two best places to live? How the prices compare?
# - How venues distribute among Manhattan neighborhoods and around metro stations?
# - Are there tradeoffs between size and price and location?
# - Any other interesting statistical data findings of the real estate and overall data.

# %% [markdown]
# ### Reference of venues around current residence in Singapore for comparison to Manhattan place

# %%
# Shenton Way, District 01, Singapore
address = 'Mccallum Street, Singapore'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Singapore home are {}, {}.'.format(latitude, longitude))
# Out:
# /Users/henryhong/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   after removing the cwd from sys.path.
# The geograpical coordinate of Singapore home are 1.2792423, 103.8481312.

# %%
neighborhood_latitude=1.2792655
neighborhood_longitude=103.8480938

# %%
credential = json.loads(open('Foursquare_Credential.json').read())

# %%
CLIENT_ID = credential['client_id']
CLIENT_SECRET = credential['client_secret']
VERSION = '20180605' # Foursquare API version

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 500 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d221a24d29cbb1d38c51f0e'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51b49e49abd88dd0b4e7330f-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'primary': True,
#          'shortName': 'Wine Bar'}],
#        'id': '51b49e49abd88dd0b4e7330f',
#        'location': {'address': '206 Telok Ayer Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 112,
#         'formattedAddress': ['206 Telok Ayer Street', '068641', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2799249387439204,
#           'lng': 103.84733300574288}],
#         'lat': 1.2799249387439204,
#         'lng': 103.84733300574288,
#         'neighborhood': 'Tanjong Pagar',
#         'postalCode': '068641'},
#        'name': 'Napoleon Food & Wine Bar',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '58378307'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50248ddde4b0bb3db3a6ff8a-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '50248ddde4b0bb3db3a6ff8a',
#        'location': {'address': '#02-102, Amoy Street Food Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '7 Maxwell Rd.',
#         'distance': 154,
#         'formattedAddress': ['#02-102, Amoy Street Food Centre (7 Maxwell Rd.)',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.279371,
#           'lng': 103.84671}],
#         'lat': 1.279371,
#         'lng': 103.84671},
#        'name': 'Pepper Bowl',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-586a792404aa4f25645e4e4e-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '586a792404aa4f25645e4e4e',
#        'location': {'address': '52A Amoy Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 169,
#         'formattedAddress': ['52A Amoy Street', '069878', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2801354244146959,
#           'lng': 103.84684430802805}],
#         'lat': 1.2801354244146959,
#         'lng': 103.84684430802805,
#         'postalCode': '069878'},
#        'name': 'Native',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55a49050498e801fbf03be73-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d146941735',
#          'name': 'Deli / Bodega',
#          'pluralName': 'Delis / Bodegas',
#          'primary': True,
#          'shortName': 'Deli / Bodega'}],
#        'id': '55a49050498e801fbf03be73',
#        'location': {'address': '179 Telok Ayer St',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': 'Amoy St',
#         'distance': 112,
#         'formattedAddress': ['179 Telok Ayer St (Amoy St)',
#          '068627',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2798723608759432,
#           'lng': 103.84728710112705}],
#         'lat': 1.2798723608759432,
#         'lng': 103.84728710112705,
#         'neighborhood': 'Chinatown',
#         'postalCode': '068627'},
#        'name': 'Park Bench Deli',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f704af9e4b07a4bc6edd2a9-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4f704af9e4b07a4bc6edd2a9',
#        'location': {'address': '35 Robinson Road',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 219,
#         'formattedAddress': ['35 Robinson Road', '068876', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280123733393359,
#           'lng': 103.84986688322}],
#         'lat': 1.280123733393359,
#         'lng': 103.84986688322,
#         'postalCode': '068876'},
#        'name': 'Sofitel So Singapore',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '150895632'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56e9512acd10cabb2f042d09-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/beergarden_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d117941735',
#          'name': 'Beer Garden',
#          'pluralName': 'Beer Gardens',
#          'primary': True,
#          'shortName': 'Beer Garden'}],
#        'id': '56e9512acd10cabb2f042d09',
#        'location': {'address': '21A Boon Tat Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 226,
#         'formattedAddress': ['21A Boon Tat Street', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812544915596238,
#           'lng': 103.8485128808929}],
#         'lat': 1.2812544915596238,
#         'lng': 103.8485128808929},
#        'name': 'Freehouse',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c57877d6201e21e49b7e86e-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4c57877d6201e21e49b7e86e',
#        'location': {'address': '45 Ann Siang Hill #02-02',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': 'Ann Siang Hill Park',
#         'distance': 243,
#         'formattedAddress': ['45 Ann Siang Hill #02-02 (Ann Siang Hill Park)',
#          '069719',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2804684376763578,
#           'lng': 103.8462642876152}],
#         'lat': 1.2804684376763578,
#         'lng': 103.8462642876152,
#         'neighborhood': 'Chinatown',
#         'postalCode': '069719'},
#        'name': 'PS.Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b6a6236f964a5200fd42be3-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4b6a6236f964a5200fd42be3',
#        'location': {'address': '#02-78 Amoy Street Food Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '7 Maxwell Road',
#         'distance': 158,
#         'formattedAddress': ['#02-78 Amoy Street Food Centre (7 Maxwell Road)',
#          '069111',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2795293,
#           'lng': 103.846695}],
#         'lat': 1.2795293,
#         'lng': 103.846695,
#         'postalCode': '069111'},
#        'name': 'Coffee Break',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5ba8e7638b98fd002c7c2b1f-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dumplings_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d108941735',
#          'name': 'Dumpling Restaurant',
#          'pluralName': 'Dumpling Restaurants',
#          'primary': True,
#          'shortName': 'Dumplings'}],
#        'id': '5ba8e7638b98fd002c7c2b1f',
#        'location': {'address': '44 Amoy Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 186,
#         'formattedAddress': ['44 Amoy Street', '069870', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2804831833097174,
#           'lng': 103.84694151071514}],
#         'lat': 1.2804831833097174,
#         'lng': 103.84694151071514,
#         'neighborhood': 'Chinatown',
#         'postalCode': '069870'},
#        'name': 'Dumpling Darlings',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5bab10b9364d97002cc5e458-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d153941735',
#          'name': 'Burrito Place',
#          'pluralName': 'Burrito Places',
#          'primary': True,
#          'shortName': 'Burritos'}],
#        'id': '5bab10b9364d97002cc5e458',
#        'location': {'address': '#01-01 Frasers Tower',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '182 Cecil Street',
#         'distance': 120,
#         'formattedAddress': ['#01-01 Frasers Tower (182 Cecil Street)',
#          '069547',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2790721332821124,
#           'lng': 103.84702556749504}],
#         'lat': 1.2790721332821124,
#         'lng': 103.84702556749504,
#         'neighborhood': 'Financial District',
#         'postalCode': '069547'},
#        'name': 'Muchachos',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-50095587e4b078f59fa0aa8e-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'primary': True,
#          'shortName': 'Desserts'}],
#        'id': '50095587e4b078f59fa0aa8e',
#        'location': {'address': '44 Amoy Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 184,
#         'formattedAddress': ['44 Amoy Street', '069870', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2804615934724815,
#           'lng': 103.84695041484888}],
#         'lat': 1.2804615934724815,
#         'lng': 103.84695041484888,
#         'postalCode': '069870'},
#        'name': "Matt's | The Chocolate Shop",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56ecb93dcd101850ebc08dc5-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '56ecb93dcd101850ebc08dc5',
#        'location': {'address': '77 Robinson Road #01-03',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 161,
#         'formattedAddress': ['77 Robinson Road #01-03', '068896', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2778141065087054,
#           'lng': 103.84818781617354}],
#         'lat': 1.2778141065087054,
#         'lng': 103.84818781617354,
#         'postalCode': '068896'},
#        'name': 'Mellower Coffee',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e5e1aefe4cdfc603ed5c7c3-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'primary': True,
#          'shortName': 'Korean'}],
#        'id': '4e5e1aefe4cdfc603ed5c7c3',
#        'location': {'address': '98 Amoy St',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 239,
#         'formattedAddress': ['98 Amoy St', '069918', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.281345203093981,
#           'lng': 103.84755092069813}],
#         'lat': 1.281345203093981,
#         'lng': 103.84755092069813,
#         'postalCode': '069918'},
#        'name': '왕대박 Wang Dae Bak Korean BBQ Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59256e0228122f403d2959ab-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b79f9',
#          'name': 'Modern European Restaurant',
#          'pluralName': 'Modern European Restaurants',
#          'primary': True,
#          'shortName': 'Modern European'}],
#        'id': '59256e0228122f403d2959ab',
#        'location': {'address': '72 Amoy Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 186,
#         'formattedAddress': ['72 Amoy Street', '069893', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802674,
#           'lng': 103.84675}],
#         'lat': 1.2802674,
#         'lng': 103.84675,
#         'postalCode': '069893'},
#        'name': 'Nouri',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b305537f964a520fef824e3-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'primary': True,
#          'shortName': 'Food Court'}],
#        'id': '4b305537f964a520fef824e3',
#        'location': {'address': '7 Maxwell Rd',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': 'Telok Ayer St / Amoy St',
#         'distance': 113,
#         'formattedAddress': ['7 Maxwell Rd (Telok Ayer St / Amoy St)',
#          '069111',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2793678520661573,
#           'lng': 103.84707897656013}],
#         'lat': 1.2793678520661573,
#         'lng': 103.84707897656013,
#         'neighborhood': 'Financial District',
#         'postalCode': '069111'},
#        'name': 'Amoy Street Food Centre',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-551bd574498e5f30136a811e-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '551bd574498e5f30136a811e',
#        'location': {'address': '19 Boon Tat Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 229,
#         'formattedAddress': ['19 Boon Tat Street', '069619', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812964408600642,
#           'lng': 103.8484369192239}],
#         'lat': 1.2812964408600642,
#         'lng': 103.8484369192239,
#         'postalCode': '069619'},
#        'name': 'FYR Cycene Ond Drinc',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4fc8aecee4b08eb1f57a1a81-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4fc8aecee4b08eb1f57a1a81',
#        'location': {'address': '1 Shenton Way',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 227,
#         'formattedAddress': ['1 Shenton Way', '068803', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2790836483039665,
#           'lng': 103.85012677894278}],
#         'lat': 1.2790836483039665,
#         'lng': 103.85012677894278,
#         'neighborhood': 'Financial District',
#         'postalCode': '068803'},
#        'name': 'Anglo Indian Cafe & Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-543e53f6498e8eacbba09d5e-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'primary': True,
#          'shortName': 'Korean'}],
#        'id': '543e53f6498e8eacbba09d5e',
#        'location': {'address': '182 Telok Ayer Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 149,
#         'formattedAddress': ['182 Telok Ayer Street', '068630', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280479036515832,
#           'lng': 103.84752160405156}],
#         'lat': 1.280479036515832,
#         'lng': 103.84752160405156,
#         'neighborhood': 'Chinatown',
#         'postalCode': '068630'},
#        'name': 'Oven & Fried Chicken',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a0a815ab546184394622ff6-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '5a0a815ab546184394622ff6',
#        'location': {'address': '11/12 Stanley Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 121,
#         'formattedAddress': ['11/12 Stanley Street', '068734', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2803394109655468,
#           'lng': 103.8478881267848}],
#         'lat': 1.2803394109655468,
#         'lng': 103.8478881267848,
#         'postalCode': '068734',
#         'state': 'Singapore'},
#        'name': 'Common Man Stan',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e741c8baeb780be09a0321f-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'primary': True,
#          'shortName': 'Sandwiches'}],
#        'id': '4e741c8baeb780be09a0321f',
#        'location': {'address': '136 Telok Ayer St',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 251,
#         'formattedAddress': ['136 Telok Ayer St', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2815286862041824,
#           'lng': 103.84811698897273}],
#         'lat': 1.2815286862041824,
#         'lng': 103.84811698897273},
#        'name': 'Sarnies',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58181cfd38fa17eb24ba32fa-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '58181cfd38fa17eb24ba32fa',
#        'location': {'address': '#06-01 Tanjong Pagar Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '7 Wallich Street',
#         'distance': 307,
#         'formattedAddress': ['#06-01 Tanjong Pagar Centre (7 Wallich Street)',
#          '078884',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2770546200166835,
#           'lng': 103.84643542061019}],
#         'lat': 1.2770546200166835,
#         'lng': 103.84643542061019,
#         'postalCode': '078884'},
#        'name': 'Virgin Active',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-557a6b3c498ed9cb15987433-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '557a6b3c498ed9cb15987433',
#        'location': {'address': '8 Stanley Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 101,
#         'formattedAddress': ['8 Stanley Street', '068727', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280110799343203,
#           'lng': 103.8477615067585}],
#         'lat': 1.280110799343203,
#         'lng': 103.8477615067585,
#         'postalCode': '068727'},
#        'name': 'ShuKuu Izakaya',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56d3c557cd10357fe7eb429e-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'primary': True,
#          'shortName': 'Korean'}],
#        'id': '56d3c557cd10357fe7eb429e',
#        'location': {'address': '123 Telok Ayer Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 227,
#         'formattedAddress': ['123 Telok Ayer Street', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2812992606038325,
#           'lng': 103.84793164085784}],
#         'lat': 1.2812992606038325,
#         'lng': 103.84793164085784},
#        'name': 'Magal BBQ 마포갈매기',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51c2c98f8bbda6c871fa0bcc-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '51c2c98f8bbda6c871fa0bcc',
#        'location': {'address': 'Asia Square Tower 2, 12 Marina View',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 317,
#         'formattedAddress': ['Asia Square Tower 2, 12 Marina View',
#          '018961',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2782748644512303,
#           'lng': 103.85077194308906}],
#         'lat': 1.2782748644512303,
#         'lng': 103.85077194308906,
#         'postalCode': '018961',
#         'state': 'SG-01'},
#        'name': 'The Westin Singapore',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '63746181'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-559bcec1498ef1434e22b3c6-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '559bcec1498ef1434e22b3c6',
#        'location': {'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 237,
#         'formattedAddress': ['Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2813980779857868,
#           'lng': 103.84816324142832}],
#         'lat': 1.2813980779857868,
#         'lng': 103.84816324142832},
#        'name': "L'Operetta Corner Bar",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54e975f6498e0c8bb883ee29-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'primary': True,
#          'shortName': 'Southern / Soul'}],
#        'id': '54e975f6498e0c8bb883ee29',
#        'location': {'address': '167 Telok Ayer Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 129,
#         'formattedAddress': ['167 Telok Ayer Street', '068620', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802049410855447,
#           'lng': 103.8474104901937}],
#         'lat': 1.2802049410855447,
#         'lng': 103.8474104901937,
#         'postalCode': '068620'},
#        'name': 'Meat Smith',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '219625364'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-553b2460498e8cfc0a3cdc32-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d111941735',
#          'name': 'Japanese Restaurant',
#          'pluralName': 'Japanese Restaurants',
#          'primary': True,
#          'shortName': 'Japanese'}],
#        'id': '553b2460498e8cfc0a3cdc32',
#        'location': {'address': '15 Ann Siang Road',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 330,
#         'formattedAddress': ['15 Ann Siang Road', '069695', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2810744259693214,
#           'lng': 103.84574260981839}],
#         'lat': 1.2810744259693214,
#         'lng': 103.84574260981839,
#         'postalCode': '069695'},
#        'name': 'Yen Yakiniku',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ca579c7d971b1f7593ef7e0-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/soup_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1dd931735',
#          'name': 'Soup Place',
#          'pluralName': 'Soup Places',
#          'primary': True,
#          'shortName': 'Soup'}],
#        'id': '4ca579c7d971b1f7593ef7e0',
#        'location': {'address': '#02-129, Amoy Street Food Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '7 Maxwell Road',
#         'distance': 167,
#         'formattedAddress': ['#02-129, Amoy Street Food Centre (7 Maxwell Road)',
#          '069111',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2794006,
#           'lng': 103.846596}],
#         'lat': 1.2794006,
#         'lng': 103.846596,
#         'neighborhood': 'Financial District',
#         'postalCode': '069111'},
#        'name': 'Han Kee Fish Soup',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53db460f498e18a343d830db-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '53db460f498e18a343d830db',
#        'location': {'address': '198 Telok Ayer St',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 134,
#         'formattedAddress': ['198 Telok Ayer St', '068637', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.280137,
#           'lng': 103.847256}],
#         'lat': 1.280137,
#         'lng': 103.847256,
#         'postalCode': '068637'},
#        'name': 'Pantler',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b13fe99f964a520659b23e3-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'primary': True,
#          'shortName': 'Food Court'}],
#        'id': '4b13fe99f964a520659b23e3',
#        'location': {'address': '18 Raffles Quay',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '1 Boon Tat St.',
#         'distance': 299,
#         'formattedAddress': ['18 Raffles Quay (1 Boon Tat St.)',
#          '048582',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2805818978847052,
#           'lng': 103.85044020580223}],
#         'lat': 1.2805818978847052,
#         'lng': 103.85044020580223,
#         'postalCode': '048582'},
#        'name': 'Lau Pa Sat Festival Market',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-538eab7f498e1f5300a2f5bf-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/korean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d113941735',
#          'name': 'Korean Restaurant',
#          'pluralName': 'Korean Restaurants',
#          'primary': True,
#          'shortName': 'Korean'}],
#        'id': '538eab7f498e1f5300a2f5bf',
#        'location': {'address': '155 Telok Ayer St',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 150,
#         'formattedAddress': ['155 Telok Ayer St', '068611', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2804895337554596,
#           'lng': 103.84751591144182}],
#         'lat': 1.2804895337554596,
#         'lng': 103.84751591144182,
#         'neighborhood': 'Telok Ayer',
#         'postalCode': '068611'},
#        'name': 'Singkoba',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d24773df39ca14334e675b8-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '4d24773df39ca14334e675b8',
#        'location': {'address': '#01-56/57 7 Maxwell Road',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 80,
#         'formattedAddress': ['#01-56/57 7 Maxwell Road',
#          '069111',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2791000736241216,
#           'lng': 103.84739222011355}],
#         'lat': 1.2791000736241216,
#         'lng': 103.84739222011355,
#         'postalCode': '069111'},
#        'name': 'Quan Ji @ Amoy Street Food Market',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52c54d0411d2a3d73dae49f6-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#           'suffix': '.png'},
#          'id': '53e0feef498e5aac066fd8a9',
#          'name': 'Street Food Gathering',
#          'pluralName': 'Street Food Gatherings',
#          'primary': True,
#          'shortName': 'Street Food Gathering'}],
#        'id': '52c54d0411d2a3d73dae49f6',
#        'location': {'address': 'Boon Tat Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 306,
#         'formattedAddress': ['Boon Tat Street', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802855829763509,
#           'lng': 103.85065465718189}],
#         'lat': 1.2802855829763509,
#         'lng': 103.85065465718189},
#        'name': 'Lau Pa Sat Satay Street',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55dd3b2f498ee2d1c9ec32ec-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '55dd3b2f498ee2d1c9ec32ec',
#        'location': {'address': '#01-01/02/03, CapitaGreen',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '138 Market Street',
#         'distance': 327,
#         'formattedAddress': ['#01-01/02/03, CapitaGreen (138 Market Street)',
#          '048946',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.281468,
#           'lng': 103.850039}],
#         'lat': 1.281468,
#         'lng': 103.850039,
#         'postalCode': '048946'},
#        'name': 'Grain Traders',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4df741991f6e94c2c77ef6da-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/seafood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ce941735',
#          'name': 'Seafood Restaurant',
#          'pluralName': 'Seafood Restaurants',
#          'primary': True,
#          'shortName': 'Seafood'}],
#        'id': '4df741991f6e94c2c77ef6da',
#        'location': {'address': '20 Gemmill Lane',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 367,
#         'formattedAddress': ['20 Gemmill Lane', '069256', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2824588279356128,
#           'lng': 103.84724044318698}],
#         'lat': 1.2824588279356128,
#         'lng': 103.84724044318698,
#         'postalCode': '069256'},
#        'name': "Luke's Oyster Bar & Chop House",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-597012f67269fe3e6b17ab13-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '597012f67269fe3e6b17ab13',
#        'location': {'address': '6A Shenton Way OUE Gallery B1-07',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 198,
#         'formattedAddress': ['6A Shenton Way OUE Gallery B1-07',
#          '068809',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2780488836327972,
#           'lng': 103.84939915153375}],
#         'lat': 1.2780488836327972,
#         'lng': 103.84939915153375,
#         'neighborhood': 'Financial District',
#         'postalCode': '068809'},
#        'name': 'The Providore',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-506daac8e4b09e74d871828c-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/spanish_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d150941735',
#          'name': 'Spanish Restaurant',
#          'pluralName': 'Spanish Restaurants',
#          'primary': True,
#          'shortName': 'Spanish'}],
#        'id': '506daac8e4b09e74d871828c',
#        'location': {'address': '22 Ann Siang Hill',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': 'Ann Siang Road',
#         'distance': 330,
#         'formattedAddress': ['22 Ann Siang Hill (Ann Siang Road)',
#          '069702',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2810338519455675,
#           'lng': 103.84570753754707}],
#         'lat': 1.2810338519455675,
#         'lng': 103.84570753754707,
#         'postalCode': '069702'},
#        'name': 'Lolla',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a25322142d8c2528e5b178a-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'primary': True,
#          'shortName': 'Diner'}],
#        'id': '5a25322142d8c2528e5b178a',
#        'location': {'address': '138 Robinson Road #19-01',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': 'Oxley Tower',
#         'distance': 56,
#         'formattedAddress': ['138 Robinson Road #19-01 (Oxley Tower)',
#          '068906',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.278826,
#           'lng': 103.848354}],
#         'lat': 1.278826,
#         'lng': 103.848354,
#         'postalCode': '068906'},
#        'name': 'Myo Restobar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5580f23c498ed3f5a3270457-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '5580f23c498ed3f5a3270457',
#        'location': {'address': '52 Amoy Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 170,
#         'formattedAddress': ['52 Amoy Street', '069878', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2801395970080391,
#           'lng': 103.84683438697066}],
#         'lat': 1.2801395970080391,
#         'lng': 103.84683438697066,
#         'postalCode': '069878'},
#        'name': "Wanton Seng's Noodle Bar",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-59410e436f706a795d106c76-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '55a59bace4b013909087cb24',
#          'name': 'Ramen Restaurant',
#          'pluralName': 'Ramen Restaurants',
#          'primary': True,
#          'shortName': 'Ramen'}],
#        'id': '59410e436f706a795d106c76',
#        'location': {'address': '7 Wallich Street #01-15 Tanjong Pagar Centre, Tanjong Pagar Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '5 Wallich St',
#         'distance': 354,
#         'formattedAddress': ['7 Wallich Street #01-15 Tanjong Pagar Centre, Tanjong Pagar Centre (5 Wallich St)',
#          '078884',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.27707,
#           'lng': 103.84579}],
#         'lat': 1.27707,
#         'lng': 103.84579,
#         'neighborhood': 'Financial District',
#         'postalCode': '078884'},
#        'name': 'Ippudo (一風堂)',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b05880bf964a520eaad22e3-40',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4b05880bf964a520eaad22e3',
#        'location': {'address': '33 Erskine Road',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 336,
#         'formattedAddress': ['33 Erskine Road', '069333', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2807069667371653,
#           'lng': 103.84543116452546}],
#         'lat': 1.2807069667371653,
#         'lng': 103.84543116452546,
#         'postalCode': '069333'},
#        'name': 'The Scarlet',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-511b32ade4b028f8d3314584-41',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d1941735',
#          'name': 'Noodle House',
#          'pluralName': 'Noodle Houses',
#          'primary': True,
#          'shortName': 'Noodles'}],
#        'id': '511b32ade4b028f8d3314584',
#        'location': {'address': '#01-39 Amoy Street Food Centre',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '7 Maxwell Rd',
#         'distance': 165,
#         'formattedAddress': ['#01-39 Amoy Street Food Centre (7 Maxwell Rd)',
#          '069111',
#          'Singapore'],
# ...
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 250,
#         'formattedAddress': ['Capital Tower #01-10', '068912', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2770746709229392,
#           'lng': 103.84757986038572}],
#         'lat': 1.2770746709229392,
#         'lng': 103.84757986038572,
#         'postalCode': '068912'},
#        'name': 'En Sakaba',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-594bb4e0a2c00b06319e2130-87',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'primary': True,
#          'shortName': 'Bar'}],
#        'id': '594bb4e0a2c00b06319e2130',
#        'location': {'cc': 'SG',
#         'city': 'Tanjong Pagar',
#         'country': 'Singapore',
#         'crossStreet': 'Cook St Alley',
#         'distance': 436,
#         'formattedAddress': ['Cook St Alley', '088463', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2789584,
#           'lng': 103.84418}],
#         'lat': 1.2789584,
#         'lng': 103.84418,
#         'postalCode': '088463',
#         'state': 'Singapore'},
#        'name': 'Junior',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-536398f011d225cf26b2de9a-88',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/cocktails_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11e941735',
#          'name': 'Cocktail Bar',
#          'pluralName': 'Cocktail Bars',
#          'primary': True,
#          'shortName': 'Cocktail'}],
#        'id': '536398f011d225cf26b2de9a',
#        'location': {'address': '#B1-01, 7 Ann Siang Hill',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 359,
#         'formattedAddress': ['#B1-01, 7 Ann Siang Hill', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2814085040906469,
#           'lng': 103.845677521132}],
#         'lat': 1.2814085040906469,
#         'lng': 103.845677521132},
#        'name': 'Operation Dagger',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b625e08f964a5208f442ae3-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_martialarts_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d101941735',
#          'name': 'Martial Arts Dojo',
#          'pluralName': 'Martial Arts Dojos',
#          'primary': True,
#          'shortName': 'Martial Arts'}],
#        'id': '4b625e08f964a5208f442ae3',
#        'location': {'address': '26 China Street, #01-01',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': 'Cross Street',
#         'distance': 412,
#         'formattedAddress': ['26 China Street, #01-01 (Cross Street)',
#          '049568',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2829673982020517,
#           'lng': 103.84806217253097}],
#         'lat': 1.2829673982020517,
#         'lng': 103.84806217253097,
#         'postalCode': '049568'},
#        'name': 'EvolveMMA Far East Square',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-58255545b244c8385714dd29-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'primary': True,
#          'shortName': 'Salad'}],
#        'id': '58255545b244c8385714dd29',
#        'location': {'address': '#B2-16 Tanjong Pagar Centre',
#         'cc': 'SG',
#         'city': 'Tanjong Pagar',
#         'country': 'Singapore',
#         'crossStreet': '7 Wallich Street',
#         'distance': 423,
#         'formattedAddress': ['#B2-16 Tanjong Pagar Centre (7 Wallich Street)',
#          '078884',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2767265621171775,
#           'lng': 103.8452612818406}],
#         'lat': 1.2767265621171775,
#         'lng': 103.8452612818406,
#         'postalCode': '078884',
#         'state': 'Singapore'},
#        'name': 'The Daily Cut',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a3cedd52619ee7032f8903c-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '5a3cedd52619ee7032f8903c',
#        'location': {'address': '28 Ann Siang Road B1',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 312,
#         'formattedAddress': ['28 Ann Siang Road B1', '069708', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2808603852749922,
#           'lng': 103.84578798136066}],
#         'lat': 1.2808603852749922,
#         'lng': 103.84578798136066,
#         'neighborhood': 'Financial District',
#         'postalCode': '069708'},
#        'name': 'Blue Label',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-592a85ba8d0a53502937bbd2-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'primary': True,
#          'shortName': 'Desserts'}],
#        'id': '592a85ba8d0a53502937bbd2',
#        'location': {'address': '53 Tras Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 432,
#         'formattedAddress': ['53 Tras Street', '078992', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2779778063824219,
#           'lng': 103.84442755714727}],
#         'lat': 1.2779778063824219,
#         'lng': 103.84442755714727,
#         'postalCode': '078992'},
#        'name': 'Nesuto Patisserie',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5a7a977c872f7d3916e199f9-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '5a7a977c872f7d3916e199f9',
#        'location': {'address': 'Hong Leong Building',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'crossStreet': '#01-08',
#         'distance': 343,
#         'formattedAddress': ['Hong Leong Building (#01-08)', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2811961463460806,
#           'lng': 103.85050239068553}],
#         'lat': 1.2811961463460806,
#         'lng': 103.85050239068553},
#        'name': 'Alchemist',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5b2b3525cd441c002cfa5f34-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'primary': True,
#          'shortName': 'Wine Bar'}],
#        'id': '5b2b3525cd441c002cfa5f34',
#        'location': {'address': '7-9 Club Street',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 402,
#         'formattedAddress': ['7-9 Club Street', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.282742477971281,
#           'lng': 103.84708897443797}],
#         'lat': 1.282742477971281,
#         'lng': 103.84708897443797},
#        'name': 'Merci Marcel Club Street',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5919373a5315935b271a1f4f-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'primary': True,
#          'shortName': 'Food Court'}],
#        'id': '5919373a5315935b271a1f4f',
#        'location': {'address': 'Cross Street',
#         'cc': 'SG',
#         'country': 'Singapore',
#         'distance': 298,
#         'formattedAddress': ['Cross Street', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2818123282939404,
#           'lng': 103.84893376891537}],
#         'lat': 1.2818123282939404,
#         'lng': 103.84893376891537},
#        'name': 'Market Street Interim Hawker Centre',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-566b5dbc498e50a39a4d4c29-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '54135bf5e4b08f3d2429dfdd',
#          'name': 'North Indian Restaurant',
#          'pluralName': 'North Indian Restaurants',
#          'primary': True,
#          'shortName': 'North Indian'}],
#        'id': '566b5dbc498e50a39a4d4c29',
#        'location': {'address': '18 Raffles Quay, #01-96',
#         'cc': 'SG',
#         'city': 'Singapore 048582',
#         'country': 'Singapore',
#         'crossStreet': 'Lau Pa Sat Telok Ayer Festive Market',
#         'distance': 304,
#         'formattedAddress': ['18 Raffles Quay, #01-96 (Lau Pa Sat Telok Ayer Festive Market)',
#          '048582',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2802443099838159,
#           'lng': 103.85065019741309}],
#         'lat': 1.2802443099838159,
#         'lng': 103.85065019741309,
#         'neighborhood': 'Financial District',
#         'postalCode': '048582'},
#        'name': 'Urban Roti',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-509e78c4e4b01b9e499cf2a5-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hostel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ee931735',
#          'name': 'Hostel',
#          'pluralName': 'Hostels',
#          'primary': True,
#          'shortName': 'Hostel'}],
#        'id': '509e78c4e4b01b9e499cf2a5',
#        'location': {'address': 'South Bridge Road',
#         'cc': 'SG',
#         'city': 'Chinatown',
#         'country': 'Singapore',
#         'crossStreet': '259 South Bridge Road',
#         'distance': 461,
#         'formattedAddress': ['South Bridge Road (259 South Bridge Road)',
#          '58808',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2822552089491077,
#           'lng': 103.84521682292143}],
#         'lat': 1.2822552089491077,
#         'lng': 103.84521682292143,
#         'postalCode': '58808'},
#        'name': 'Adler Hostel',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '77554945'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d53753b5c9d236a282bf3ce-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '4d53753b5c9d236a282bf3ce',
#        'location': {'address': '#01-02 Red Dot Traffic Building',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 263,
#         'formattedAddress': ['#01-02 Red Dot Traffic Building',
#          '069115',
#          'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.2779313695606225,
#           'lng': 103.84613475409516}],
#         'lat': 1.2779313695606225,
#         'lng': 103.84613475409516,
#         'neighborhood': 'Tanjong Pagar',
#         'postalCode': '069115'},
#        'name': 'Otto Ristorante Italiano',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-594373c7829b0c54bfae0ca6-99',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '594373c7829b0c54bfae0ca6',
#        'location': {'address': '140 Robinson Road',
#         'cc': 'SG',
#         'city': 'Singapore',
#         'country': 'Singapore',
#         'distance': 127,
#         'formattedAddress': ['140 Robinson Road', '068907', 'Singapore'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 1.278181023509077,
#           'lng': 103.84846582949375}],
#         'lat': 1.278181023509077,
#         'lng': 103.84846582949375,
#         'postalCode': '068907'},
#        'name': 'Plain Vanilla',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Financial District, Singapore',
#   'headerLocation': 'Financial District',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 1.2837655045000045,
#     'lng': 103.85258652226942},
#    'sw': {'lat': 1.2747654954999954, 'lng': 103.84360107773058}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 178}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
SGnearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
SGnearby_venues =SGnearby_venues.loc[:, filtered_columns]

# filter the category for each row
SGnearby_venues['venue.categories'] = SGnearby_venues.apply(get_category_type, axis=1)

# clean columns
SGnearby_venues.columns = [col.split(".")[-1] for col in SGnearby_venues.columns]

SGnearby_venues.head(10)
# Out:
#                        name           categories       lat         lng
# 0  Napoleon Food & Wine Bar             Wine Bar  1.279925  103.847333
# 1               Pepper Bowl     Asian Restaurant  1.279371  103.846710
# 2                    Native         Cocktail Bar  1.280135  103.846844
# 3           Park Bench Deli        Deli / Bodega  1.279872  103.847287
# 4      Sofitel So Singapore                Hotel  1.280124  103.849867
# 5                 Freehouse          Beer Garden  1.281254  103.848513
# 6                   PS.Cafe                 Café  1.280468  103.846264
# 7              Coffee Break          Coffee Shop  1.279529  103.846695
# 8         Dumpling Darlings  Dumpling Restaurant  1.280483  103.846942
# 9                 Muchachos        Burrito Place  1.279072  103.847026

# %% [markdown]
# ### Map of Singapore with venues near residence place - for reference

# %%
# create map of Singapore place  using latitude and longitude values
map_sg = folium.Map(location=[latitude, longitude], zoom_start=20)

# add markers to map
for lat, lng, label in zip(SGnearby_venues['lat'], SGnearby_venues['lng'], SGnearby_venues['name']):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=4,
        radius=10,
        popup=label,
        color='blue',
        fill_color='#0f0f0f',
        fill_opacity=0.7,
    ).add_to(map_sg)  
    
map_sg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 3.	Methodology section

# %% [markdown]
# ## 4.	Results section

# %% [markdown]
# ## 5.	Discussion section

# %% [markdown]
# ## 6.	Conclusion section

# %% [markdown]
# ### 1.	Introduction Section :
#
#     1.1 Discussion of the "backgroung situation" leading to the problem at hand:
#
#     1.2 Problem to be resolved
#
#     1.3 Audience for this project.
#
# ### 2.	Data Section:
#
# 	2.1 Data of Current Situation (current residence place)
#
#     2.2 Data required to resolve the problem
#
#     2.3 Data sources and data manipulation
#
# ### 3.	Methodology section :
#
# 	3.1 Process steps and strategy to resolve the problem
#
#     3.2 Data Science Methods, machine learing, mapping tools and exploratory data analysis.
#
# ### 4.	Results section
#
# 	Discussion of the results and how they help to take a decision.
#
# ### 5.	Discussion section
#
# 	Elaboration and discussion on any observations and/or recommendations for improvement.
#
# ### 6.	Conclusion section
# 	Desicison taken and Report Conclusion.
